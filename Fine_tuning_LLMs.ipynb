# %% [markdown]
# <a href="https://colab.research.google.com/github/ghostriley08/LLMS-In-Python/blob/main/Fine_tuning_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Preparing for Fine Tuning
# Finetuning is done to adapt the model to domain psecific tasks
# Loading dataset
from datasets import load_dataset # Huggingface Dataset
# Goal : Finetune a pre-trained model with the imdb data
train_data = load_dataset("imdb",split = "train")
train_data = train_data.shard(num_shards=4,index=0)
test_data = load_dataset("imdb",split = "test")
test_data = test_data.shard(num_shards=4,index=0)
# Divide dataset to speed up training
# Extraction depends on data and computationasl needs
